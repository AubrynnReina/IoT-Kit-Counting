# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# %cd /content/drive/MyDrive/YOLO_Testing
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/YOLO_Testing

# %%
import torch
from IPython.display import Image, clear_output  # to display images

print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Setup complete. Using torch 2.1.0+cu118 (Tesla T4)

# %%
# %cd /content/drive/MyDrive/YOLO_Testing/yolov5
# Out:
# /content/drive/MyDrive/YOLO_Testing/yolov5

# %%
# !python train.py --img 1280 --batch 16 --epochs 300 --data /content/drive/MyDrive/YOLO_Testing/Our_IoT_Aug/data.yaml\
                          --weights yolov5m6.pt --freeze 10 --patience 20\
                          --hyp hyp.scratch-high.yaml
# Out:
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/YOLO_Testing/yolov5/train.py", line 61, in <module>
#     from utils.loggers import Loggers
#   File "/content/drive/MyDrive/YOLO_Testing/yolov5/utils/loggers/__init__.py", line 14, in <module>
#     from utils.loggers.clearml.clearml_utils import ClearmlLogger
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 879, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 975, in get_code
#   File "<frozen importlib._bootstrap_external>", line 1074, in get_data
# KeyboardInterrupt

# %%
# !python train.py --resume /content/drive/MyDrive/YOLO_Testing/yolov5/runs/train/exp20/weights/last.pt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 644.9/644.9 kB 8.6 MB/s eta 0:00:00
# ...
# 2023-11-04 23:03:58.741896: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-04 23:03:58.741989: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-04 23:03:58.742036: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# requirements: Ultralytics requirement ['gitpython'] not found, attempting AutoUpdate...
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 6.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 179.1 MB/s eta 0:00:00
# ...
#
# ...

# %%
# !python val.py  --weights /content/drive/MyDrive/YOLO_Testing/yolov5/runs/train/exp/weights/best.pt\
                        --data /content/drive/MyDrive/YOLO_Testing/Our_IoT_Aug/data.yaml --task test\
                        --imgsz 640 --batch-size 32
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 645.2/645.2 kB 8.6 MB/s eta 0:00:00
# ...
# val: data=/content/drive/MyDrive/YOLO_Testing/Our_IoT_Aug/data.yaml, weights=['/content/drive/MyDrive/YOLO_Testing/yolov5/runs/train/exp/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=test, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# requirements: Ultralytics requirement ['gitpython>=3.1.30'] not found, attempting AutoUpdate...
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 3.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 6.6 MB/s eta 0:00:00
# ...
#
# requirements: AutoUpdate success ✅ 5.2s, installed 1 package: ['gitpython>=3.1.30']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# ...

# %%
# !python detect.py  --weights /content/drive/MyDrive/YOLO_Testing/yolov5/runs/train/exp/weights/best.pt\
                             --source /content/drive/MyDrive/YOLO_Testing/test_nov15_existediamges/1698811617178.jpg\
                             --data /content/drive/MyDrive/YOLO_Testing/Our_IoT_Aug/data.yaml\
                             --imgsz 1536 --save-txt --save-conf --agnostic-nms
# Out:
# detect: weights=['/content/drive/MyDrive/YOLO_Testing/yolov5/runs/train/exp/weights/best.pt'], source=/content/drive/MyDrive/YOLO_Testing/test_nov15_existediamges/1698811617178.jpg, data=/content/drive/MyDrive/YOLO_Testing/Our_IoT_Aug/data.yaml, imgsz=[1536, 1536], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=True, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-211-g94e943e Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 416 layers, 140172724 parameters, 0 gradients, 208.3 GFLOPs
# ...

# %%
import torch
from PIL import Image
# Model
model = torch.hub.load('.', 'custom', path='/content/drive/MyDrive/YOLO_Testing/yolov5/runs/train/exp/weights/best.pt', source='local')

# Image
im = Image.open('/content/drive/MyDrive/YOLO_Testing/test_nov15_existediamges/1696482422403.jpg')

# Inference
results = model(im)results.pandas().xyxy[0]
# Out:
# requirements: Ultralytics requirement ['gitpython>=3.1.30'] not found, attempting AutoUpdate...
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 4.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.2 MB/s eta 0:00:00
# ...
#
# requirements: AutoUpdate success ✅ 7.5s, installed 1 package: ['gitpython>=3.1.30']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
# YOLOv5 🚀 v7.0-211-g94e943e Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 416 layers, 140172724 parameters, 0 gradients, 208.3 GFLOPs
# Adding AutoShape...
#            xmin         ymin         xmax         ymax  confidence  class  \
# 0   1993.598999   901.595337  2607.611084  1503.710693    0.886903     10
# 1   1499.419800  1991.983032  1771.390625  2302.735840    0.873941      1
# 2   1056.242676  2265.317383  1437.176270  2696.995361    0.869265     13
# ...
